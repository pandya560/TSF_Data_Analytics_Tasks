# %%
#import the dependency
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
# Out:
# C:\Users\amitp\Anaconda3\lib\site-packages\pandas\compat\_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
##loading iris data
from sklearn.datasets  import load_iris
iris=load_iris()
x=pd.DataFrame(iris.data)  #independent variables
y=pd.DataFrame(iris.target)  #dependent Variable/target

# %%
#applying the decision tree
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state =0)

clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred  = clf.predict(x_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
#checking the accuary 
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_pred)
print("Accuracy of Model",acc)
# Out:
# Accuracy of Model 1.0

# %%
# plotting the decision tree

from sklearn.tree import plot_tree

# %%
fig = plt.figure(figsize = (15,10))
tree_plot =plot_tree(clf, feature_names = x.columns, precision = 5, label = "all", filled =True);
